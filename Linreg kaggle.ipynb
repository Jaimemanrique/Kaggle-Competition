# %%
import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np

import pylab as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression as LinReg
import statsmodels.api as sm
from statsmodels.formula.api import ols
from sklearn.model_selection import train_test_split as tts
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import warnings                                              
from sklearn.exceptions import DataConversionWarning          
warnings.filterwarnings(action='ignore', category=DataConversionWarning)

# %%
traineo = pd.read_csv('./data/salaries_data.csv')
traineo.head()
# Out:
#    work_year experience_level employment_type        job_title  salary  \
# 0       2022               SE              FT    Data Engineer  140250
# 1       2022               SE              FT    Data Engineer  135000
# 2       2021               MI              FT  BI Data Analyst  100000
# 3       2021               MI              CT      ML Engineer  270000
# 4       2021               MI              FT    Data Engineer   22000
#
#   salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0             USD         140250                 US           100
# 1             USD         135000                 US           100
# 2             USD         100000                 US           100
# 3             USD         270000                 US           100
# 4             EUR          26005                 RO             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# ...

# %%
traineos = traineo.copy()

# %%
y = traineo.salary_in_usd

# %%
traineos.drop(columns = 'salary_in_usd', inplace = True)

# %%
testeo = pd.read_csv('./data/testeo.csv')
testeo.head()
# Out:
#    work_year experience_level employment_type                   job_title  \
# 0       2020               SE              FT  Machine Learning Scientist
# 1       2020               MI              FT           Lead Data Analyst
# 2       2020               MI              FT                Data Analyst
# 3       2020               MI              FT   Machine Learning Engineer
# 4       2020               MI              FT        Product Data Analyst
#
#    salary salary_currency employee_residence  remote_ratio company_location  \
# 0  260000             USD                 JP             0               JP
# 1   87000             USD                 US           100               US
# 2   85000             USD                 US           100               US
# 3  299000             CNY                 CN             0               CN
# 4  450000             INR                 IN           100               IN
#
#   company_size
# 0            S
# 1            L
# ...

# %%
total = pd.concat([traineos, testeo], axis = 0)
total.shape
# Out:
# (607, 10)

# %%
total.drop(columns = ['salary','salary_currency','employee_residence'], inplace = True)

# %%
total.head()
# Out:
#    work_year experience_level employment_type        job_title  remote_ratio  \
# 0       2022               SE              FT    Data Engineer           100
# 1       2022               SE              FT    Data Engineer           100
# 2       2021               MI              FT  BI Data Analyst           100
# 3       2021               MI              CT      ML Engineer           100
# 4       2021               MI              FT    Data Engineer             0
#
#   company_location company_size
# 0               US            M
# 1               US            M
# 2               US            M
# 3               US            L
# 4               US            L

# %%
#total = pd.get_dummies(total, columns=['job_title', 'company_location','experience_level','employment_type','company_size'], drop_first = True)
total.shape
# Out:
# (607, 7)

# %%
total.drop(columns = ['company_location','experience_level','employment_type','company_size'], inplace = True)

# %%
testeo_m = total[500:]

# %%
salaries_m=total[0:500]

# %%
X = pd.get_dummies(salaries_m, columns = ['job_title'], drop_first = True)

# %%
X
# Out:
#      work_year  remote_ratio  job_title_AI Scientist  \
# 0         2022           100                       0
# 1         2022           100                       0
# 2         2021           100                       0
# 3         2021           100                       0
# 4         2021             0                       0
# ..         ...           ...                     ...
# 495       2022           100                       0
# 496       2021             0                       0
# 497       2022           100                       0
# 498       2021           100                       0
# 499       2021           100                       0
#
#      job_title_Analytics Engineer  job_title_Applied Data Scientist  \
# 0                               0                                 0
# 1                               0                                 0
# 2                               0                                 0
# ...

# %%
X_train, X_test, y_train, y_test = tts(X, y, train_size = 0.8, test_size = 0.2, random_state = 42)

# %%
linreg=LinReg()

# %%
linreg.fit(X_test, y_test)
# Out:
# LinearRegression()

# %%
y_pred = linreg.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error as mse

# %%
mse(y_test, y_pred, squared=False)
# Out:
# 52205.09078350725

# %%
testeo_m = pd.get_dummies(testeo_m, columns = ['job_title'], drop_first = True)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((400, 49), (100, 49), (400,), (100,))

# %%
testeo_m
# Out:
#      work_year  remote_ratio  job_title_Analytics Engineer  \
# 0         2020             0                             0
# 1         2020           100                             0
# 2         2020           100                             0
# 3         2020             0                             0
# 4         2020           100                             0
# ..         ...           ...                           ...
# 102       2022           100                             0
# 103       2022           100                             0
# 104       2022           100                             0
# 105       2022             0                             0
# 106       2022             0                             0
#
#      job_title_Applied Machine Learning Scientist  job_title_BI Data Analyst  \
# 0                                               0                          0
# 1                                               0                          0
# ...

# %%
y_pred1 = linreg.predict(testeo_m)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 1>()
# ----> 1 y_pred1 = linreg.predict(testeo_m)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:362, in LinearModel.predict(self, X)
#     348 def predict(self, X):
#     349     """
#     350     Predict using the linear model.
#     351
#    (...)
#     360         Returns predicted values.
#     361     """
# --> 362     return self._decision_function(X)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_base.py:345, in LinearModel._decision_function(self, X)
#     342 def _decision_function(self, X):
#     343     check_is_fitted(self)
# --> 345     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     346     return safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
#
# ...

# %%
y_pred1

# %%
pruebaaa = pd.DataFrame(y_pred1,columns=['salary_in_usd'])
pruebaaa.to_csv('./data/pruebaaa.csv',index_label='id')
